# %%
import cv2
from ultralytics import YOLO

def detect_objects_from_usb_camera(model_path='best-111.pt', camera_index=0):
    """
    Perform real-time object detection using YOLOv8 from a USB camera.

    Args:
        model_path (str): Path to the YOLOv8 model to use (e.g., 'yolov8n.pt', 'yolov8m.pt').
                          If not specified, 'yolov8n.pt' (Nano model) will be downloaded automatically.
        camera_index (int): Index of the USB camera to use.
                            Typically, the default camera is 0.
                            If you have multiple cameras, try 1, 2, etc.
    """

    # Load the YOLOv8 model
    # The specified model will be downloaded automatically the first time it's run
    model = YOLO(model_path)

    # Initialize the USB camera
    cap = cv2.VideoCapture(camera_index)

    # Check if the camera was opened successfully
    if not cap.isOpened():
        print(f"Error: Could not open camera {camera_index}. Please check the camera index.")
        return

    print("Starting real-time object detection. Press 'q' to quit.")

    while True:
        # Read a frame from the camera
        ret, frame = cap.read()

        # Check if the frame was read successfully
        if not ret:
            print("Error: Could not read frame. Exiting.")
            break

        # Perform object detection with YOLOv8
        # Using stream=True returns results as a generator, which is memory-efficient
        # for processing a large number of frames.
        results = model(frame, stream=True)

        # Draw detection results on the frame
        for r in results:
            # Get bounding box, class, and confidence for detected objects
            # r.boxes contains the detection results
            for box in r.boxes:
                x1, y1, x2, y2 = map(int, box.xyxy[0]) # Bounding box coordinates
                confidence = float(box.conf[0])       # Confidence score
                class_id = int(box.cls[0])            # Class ID
                class_name = model.names[class_id]    # Class name

                # Draw the bounding box
                cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2) # Green rectangle

                # Draw the text (class name and confidence)
                label = f"{class_name}: {confidence:.2f}"
                cv2.putText(frame, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

        # Display the result
        cv2.imshow("YOLOv8 USB Camera Detection", frame)

        # Exit the loop if 'q' key is pressed
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    # Release resources
    cap.release()
    cv2.destroyAllWindows()
    print("Detection stopped.")

# %%
detect_objects_from_usb_camera(model_path='best-111.pt', camera_index=0)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 detect_objects_from_usb_camera(model_path='best-111.pt', camera_index=0)
#
# Cell In[2], line 18, in detect_objects_from_usb_camera(model_path, camera_index)
#       5 """
#       6 Perform real-time object detection using YOLOv8 from a USB camera.
#       7
#    (...)     13                         If you have multiple cameras, try 1, 2, etc.
#      14 """
#      16 # Load the YOLOv8 model
#      17 # The specified model will be downloaded automatically the first time it's run
# ---> 18 model = YOLO(model_path)
#      20 # Initialize the USB camera
#      21 cap = cv2.VideoCapture(camera_index)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\ultralytics\models\yolo\model.py:23, in YOLO.__init__(self, model, task, verbose)
#      20     self.__dict__ = new_instance.__dict__
#      21 else:
#      22     # Continue with default YOLO initialization
# ---> 23     super().__init__(model=model, task=task, verbose=verbose)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\ultralytics\engine\model.py:148, in Model.__init__(self, model, task, verbose)
#     146     self._new(model, task=task, verbose=verbose)
#     147 else:
# --> 148     self._load(model, task=task)
#     150 # Delete super().training for accessing self.model.training
#     151 del self.training
#
# File ~\AppData\Roaming\Python\Python312\site-packages\ultralytics\engine\model.py:290, in Model._load(self, weights, task)
#     287 weights = checks.check_model_file_from_stem(weights)  # add suffix, i.e. yolo11n -> yolo11n.pt
#     289 if Path(weights).suffix == ".pt":
# --> 290     self.model, self.ckpt = attempt_load_one_weight(weights)
#     291     self.task = self.model.args["task"]
#     292     self.overrides = self.model.args = self._reset_ckpt_args(self.model.args)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\ultralytics\nn\tasks.py:1039, in attempt_load_one_weight(weight, device, inplace, fuse)
#    1026 def attempt_load_one_weight(weight, device=None, inplace=True, fuse=False):
#    1027     """
#    1028     Load a single model weights.
#    1029
#    (...)   1037         (tuple): Tuple containing the model and checkpoint.
#    1038     """
# -> 1039     ckpt, weight = torch_safe_load(weight)  # load ckpt
#    1040     args = {**DEFAULT_CFG_DICT, **(ckpt.get("train_args", {}))}  # combine model and default args, preferring model args
#    1041     model = (ckpt.get("ema") or ckpt["model"]).to(device).float()  # FP32 model
#
# File ~\AppData\Roaming\Python\Python312\site-packages\ultralytics\nn\tasks.py:944, in torch_safe_load(weight, safe_only)
#     942                 ckpt = torch.load(f, pickle_module=safe_pickle)
#     943         else:
# --> 944             ckpt = torch.load(file, map_location="cpu")
#     946 except ModuleNotFoundError as e:  # e.name is missing module name
#     947     if e.name == "models":
#
# File ~\AppData\Roaming\Python\Python312\site-packages\ultralytics\utils\patches.py:86, in torch_load(*args, **kwargs)
#      83 if TORCH_1_13 and "weights_only" not in kwargs:
#      84     kwargs["weights_only"] = False
# ---> 86 return _torch_load(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\serialization.py:1525, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1523             except pickle.UnpicklingError as e:
#    1524                 raise pickle.UnpicklingError(_get_wo_message(str(e))) from None
# -> 1525         return _load(
#    1526             opened_zipfile,
#    1527             map_location,
#    1528             pickle_module,
#    1529             overall_storage=overall_storage,
#    1530             **pickle_load_args,
#    1531         )
#    1532 if mmap:
#    1533     f_name = "" if not isinstance(f, str) else f"{f}, "
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\serialization.py:2114, in _load(zip_file, map_location, pickle_module, pickle_file, overall_storage, **pickle_load_args)
#    2112 global _serialization_tls
#    2113 _serialization_tls.map_location = map_location
# -> 2114 result = unpickler.load()
#    2115 _serialization_tls.map_location = None
#    2117 torch._utils._validate_loaded_sparse_tensors()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\serialization.py:2077, in _load.<locals>.persistent_load(saved_id)
#    2075     typed_storage = loaded_storages[key]
#    2076 else:
# -> 2077     nbytes = numel * torch._utils._element_size(dtype)
#    2078     typed_storage = load_tensor(
#    2079         dtype, nbytes, key, _maybe_decode_ascii(location)
#    2080     )
#    2082 return typed_storage
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\__init__.py:2690, in __getattr__(name)
#    2687 if name in _lazy_modules:
#    2688     return importlib.import_module(f".{name}", __name__)
# -> 2690 raise AttributeError(f"module '{__name__}' has no attribute '{name}'")
#
# AttributeError: module 'torch' has no attribute '_utils'
