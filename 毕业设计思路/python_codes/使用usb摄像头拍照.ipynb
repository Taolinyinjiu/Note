# %%
import cv2
import os

# %%
def add_prefix_to_filenames(folder_path, prefix):
    """
    遍历指定文件夹下的所有文件，并在文件名中添加指定的前缀。

    Args:
        folder_path (str): 要遍历的文件夹的路径。
        prefix (str): 要添加到文件名前缀的字符串。
    """
    try:
        for filename in os.listdir(folder_path):
            old_filepath = os.path.join(folder_path, filename)

            # 确保是文件，跳过子文件夹
            if os.path.isfile(old_filepath):
                new_filename = prefix + filename
                new_filepath = os.path.join(folder_path, new_filename)

                # 重命名文件
                os.rename(old_filepath, new_filepath)
                print(f"文件 '{filename}' 重命名为 '{new_filename}'")

        print(f"已完成对文件夹 '{folder_path}' 下所有文件的重命名。")

    except FileNotFoundError:
        print(f"错误：文件夹 '{folder_path}' 不存在。")
    except Exception as e:
        print(f"发生错误：{e}")

# %%
def capture_and_save(save_path="captured_images"):
    """
    从 USB 摄像头捕获图像，并在按下 'a' 键时保存到指定路径。

    Args:
        save_path (str): 保存图像的路径。默认为 'captured_images' 文件夹。
    """
    cap = cv2.VideoCapture(0)  # 打开默认摄像头

    if not cap.isOpened():
        print("无法打开摄像头")
        return

    # 创建保存图像的文件夹（如果不存在）
    if not os.path.exists(save_path):
        os.makedirs(save_path)

    # cv2.namedWindow("Camera Feed", cv2.WINDOW_KEEPRATIO)
    image_count = 1

    while True:
        ret, frame = cap.read()
        if not ret:
            print("无法接收到帧 (stream end?). 退出 ...")
            break

        cv2.imshow("Camera Feed", frame)

        key = cv2.waitKey(1) & 0xFF
        if key == ord('q'):  # 按下 'q' 退出程序
            break
        elif key == ord('a'):  # 按下 'a' 保存图像
            filename = os.path.join(save_path, f"image_{image_count:04d}.jpg")
            cv2.imwrite(filename, frame)
            print(f"图像已保存到: {filename}")
            image_count += 1

    cap.release()
    cv2.destroyAllWindows()

# %%
save_directory = "Electronic"  # 你可以修改为你希望保存的路径
capture_and_save(save_directory)
# Out:
# 图像已保存到: Electronic\image_0001.jpg
# 图像已保存到: Electronic\image_0002.jpg
# 图像已保存到: Electronic\image_0003.jpg
# 图像已保存到: Electronic\image_0004.jpg
# 图像已保存到: Electronic\image_0005.jpg
# 图像已保存到: Electronic\image_0006.jpg
# 图像已保存到: Electronic\image_0007.jpg
# 图像已保存到: Electronic\image_0008.jpg
# 图像已保存到: Electronic\image_0009.jpg
# 图像已保存到: Electronic\image_0010.jpg
# 图像已保存到: Electronic\image_0011.jpg
# 图像已保存到: Electronic\image_0012.jpg
# 图像已保存到: Electronic\image_0013.jpg
# 图像已保存到: Electronic\image_0014.jpg
# 图像已保存到: Electronic\image_0015.jpg
# 图像已保存到: Electronic\image_0016.jpg
# 图像已保存到: Electronic\image_0017.jpg
# 图像已保存到: Electronic\image_0018.jpg
# 图像已保存到: Electronic\image_0019.jpg
# 图像已保存到: Electronic\image_0020.jpg
# 图像已保存到: Electronic\image_0021.jpg
# 图像已保存到: Electronic\image_0022.jpg
# 图像已保存到: Electronic\image_0023.jpg
# 图像已保存到: Electronic\image_0024.jpg
# 图像已保存到: Electronic\image_0025.jpg
# 图像已保存到: Electronic\image_0026.jpg
# 图像已保存到: Electronic\image_0027.jpg
# 图像已保存到: Electronic\image_0028.jpg
# 图像已保存到: Electronic\image_0029.jpg
# 图像已保存到: Electronic\image_0098.jpg
# 图像已保存到: Electronic\image_0099.jpg
# 图像已保存到: Electronic\image_0100.jpg
# 图像已保存到: Electronic\image_0101.jpg
# 图像已保存到: Electronic\image_0102.jpg
# 图像已保存到: Electronic\image_0103.jpg
# 图像已保存到: Electronic\image_0104.jpg
# 图像已保存到: Electronic\image_0105.jpg
# 图像已保存到: Electronic\image_0106.jpg
# 图像已保存到: Electronic\image_0107.jpg
# 图像已保存到: Electronic\image_0108.jpg
# 图像已保存到: Electronic\image_0109.jpg
# 图像已保存到: Electronic\image_0110.jpg
# 图像已保存到: Electronic\image_0111.jpg
# 图像已保存到: Electronic\image_0112.jpg
# 图像已保存到: Electronic\image_0113.jpg
# 图像已保存到: Electronic\image_0114.jpg
# 图像已保存到: Electronic\image_0115.jpg
# 图像已保存到: Electronic\image_0116.jpg
# 图像已保存到: Electronic\image_0117.jpg
# 图像已保存到: Electronic\image_0118.jpg
# 图像已保存到: Electronic\image_0119.jpg
# 图像已保存到: Electronic\image_0120.jpg
# 图像已保存到: Electronic\image_0121.jpg
# 图像已保存到: Electronic\image_0122.jpg
# 图像已保存到: Electronic\image_0123.jpg
# 图像已保存到: Electronic\image_0124.jpg
# 图像已保存到: Electronic\image_0125.jpg
# 图像已保存到: Electronic\image_0126.jpg
# 图像已保存到: Electronic\image_0127.jpg
# 图像已保存到: Electronic\image_0128.jpg
# 图像已保存到: Electronic\image_0129.jpg
# 图像已保存到: Electronic\image_0130.jpg
# 图像已保存到: Electronic\image_0131.jpg
# 图像已保存到: Electronic\image_0132.jpg
# 图像已保存到: Electronic\image_0133.jpg
# 图像已保存到: Electronic\image_0134.jpg
# 图像已保存到: Electronic\image_0135.jpg
# 图像已保存到: Electronic\image_0136.jpg
# 图像已保存到: Electronic\image_0137.jpg
# 图像已保存到: Electronic\image_0138.jpg
# 图像已保存到: Electronic\image_0139.jpg
# 图像已保存到: Electronic\image_0140.jpg
# 图像已保存到: Electronic\image_0141.jpg

# %%
target_folder = "Electronic"  # 替换为你要操作的文件夹路径
filename_prefix = "Electronic_"  # 你想要添加的前缀

# %%
add_prefix_to_filenames(target_folder, filename_prefix)
# Out:
# 文件 'image_0001.jpg' 重命名为 'Electronic_image_0001.jpg'
# 文件 'image_0002.jpg' 重命名为 'Electronic_image_0002.jpg'
# 文件 'image_0003.jpg' 重命名为 'Electronic_image_0003.jpg'
# 文件 'image_0004.jpg' 重命名为 'Electronic_image_0004.jpg'
# 文件 'image_0005.jpg' 重命名为 'Electronic_image_0005.jpg'
# 文件 'image_0006.jpg' 重命名为 'Electronic_image_0006.jpg'
# 文件 'image_0007.jpg' 重命名为 'Electronic_image_0007.jpg'
# 文件 'image_0008.jpg' 重命名为 'Electronic_image_0008.jpg'
# 文件 'image_0009.jpg' 重命名为 'Electronic_image_0009.jpg'
# 文件 'image_0010.jpg' 重命名为 'Electronic_image_0010.jpg'
# 文件 'image_0011.jpg' 重命名为 'Electronic_image_0011.jpg'
# 文件 'image_0012.jpg' 重命名为 'Electronic_image_0012.jpg'
# 文件 'image_0013.jpg' 重命名为 'Electronic_image_0013.jpg'
# 文件 'image_0057.jpg' 重命名为 'Electronic_image_0057.jpg'
# 文件 'image_0058.jpg' 重命名为 'Electronic_image_0058.jpg'
# 文件 'image_0059.jpg' 重命名为 'Electronic_image_0059.jpg'
# 文件 'image_0060.jpg' 重命名为 'Electronic_image_0060.jpg'
# 文件 'image_0061.jpg' 重命名为 'Electronic_image_0061.jpg'
# 文件 'image_0062.jpg' 重命名为 'Electronic_image_0062.jpg'
# 文件 'image_0063.jpg' 重命名为 'Electronic_image_0063.jpg'
# 文件 'image_0064.jpg' 重命名为 'Electronic_image_0064.jpg'
# 文件 'image_0065.jpg' 重命名为 'Electronic_image_0065.jpg'
# 文件 'image_0066.jpg' 重命名为 'Electronic_image_0066.jpg'
# 文件 'image_0067.jpg' 重命名为 'Electronic_image_0067.jpg'
# 文件 'image_0068.jpg' 重命名为 'Electronic_image_0068.jpg'
# 文件 'image_0069.jpg' 重命名为 'Electronic_image_0069.jpg'
# 文件 'image_0070.jpg' 重命名为 'Electronic_image_0070.jpg'
# 文件 'image_0071.jpg' 重命名为 'Electronic_image_0071.jpg'
# 文件 'image_0072.jpg' 重命名为 'Electronic_image_0072.jpg'
# 文件 'image_0073.jpg' 重命名为 'Electronic_image_0073.jpg'
# 文件 'image_0074.jpg' 重命名为 'Electronic_image_0074.jpg'
# 文件 'image_0075.jpg' 重命名为 'Electronic_image_0075.jpg'
# 文件 'image_0076.jpg' 重命名为 'Electronic_image_0076.jpg'
# 文件 'image_0077.jpg' 重命名为 'Electronic_image_0077.jpg'
# 文件 'image_0078.jpg' 重命名为 'Electronic_image_0078.jpg'
# 文件 'image_0079.jpg' 重命名为 'Electronic_image_0079.jpg'
# 文件 'image_0080.jpg' 重命名为 'Electronic_image_0080.jpg'
# 文件 'image_0081.jpg' 重命名为 'Electronic_image_0081.jpg'
# 文件 'image_0082.jpg' 重命名为 'Electronic_image_0082.jpg'
# 文件 'image_0083.jpg' 重命名为 'Electronic_image_0083.jpg'
# 文件 'image_0084.jpg' 重命名为 'Electronic_image_0084.jpg'
# 文件 'image_0085.jpg' 重命名为 'Electronic_image_0085.jpg'
# 文件 'image_0086.jpg' 重命名为 'Electronic_image_0086.jpg'
# 文件 'image_0087.jpg' 重命名为 'Electronic_image_0087.jpg'
# 文件 'image_0088.jpg' 重命名为 'Electronic_image_0088.jpg'
# 文件 'image_0089.jpg' 重命名为 'Electronic_image_0089.jpg'
# 文件 'image_0090.jpg' 重命名为 'Electronic_image_0090.jpg'
# 文件 'image_0091.jpg' 重命名为 'Electronic_image_0091.jpg'
# 文件 'image_0092.jpg' 重命名为 'Electronic_image_0092.jpg'
# 文件 'image_0093.jpg' 重命名为 'Electronic_image_0093.jpg'
# 文件 'image_0094.jpg' 重命名为 'Electronic_image_0094.jpg'
# 文件 'image_0095.jpg' 重命名为 'Electronic_image_0095.jpg'
# 文件 'image_0096.jpg' 重命名为 'Electronic_image_0096.jpg'
# 文件 'image_0097.jpg' 重命名为 'Electronic_image_0097.jpg'
# 文件 'image_0098.jpg' 重命名为 'Electronic_image_0098.jpg'
# 文件 'image_0099.jpg' 重命名为 'Electronic_image_0099.jpg'
# 文件 'image_0100.jpg' 重命名为 'Electronic_image_0100.jpg'
# 文件 'image_0101.jpg' 重命名为 'Electronic_image_0101.jpg'
# 文件 'image_0102.jpg' 重命名为 'Electronic_image_0102.jpg'
# 文件 'image_0103.jpg' 重命名为 'Electronic_image_0103.jpg'
# 文件 'image_0104.jpg' 重命名为 'Electronic_image_0104.jpg'
# 文件 'image_0105.jpg' 重命名为 'Electronic_image_0105.jpg'
# 文件 'image_0106.jpg' 重命名为 'Electronic_image_0106.jpg'
# 文件 'image_0107.jpg' 重命名为 'Electronic_image_0107.jpg'
# 文件 'image_0108.jpg' 重命名为 'Electronic_image_0108.jpg'
# 文件 'image_0109.jpg' 重命名为 'Electronic_image_0109.jpg'
# 文件 'image_0110.jpg' 重命名为 'Electronic_image_0110.jpg'
# 文件 'image_0111.jpg' 重命名为 'Electronic_image_0111.jpg'
# 文件 'image_0112.jpg' 重命名为 'Electronic_image_0112.jpg'
# 文件 'image_0113.jpg' 重命名为 'Electronic_image_0113.jpg'
# 文件 'image_0114.jpg' 重命名为 'Electronic_image_0114.jpg'
# 文件 'image_0115.jpg' 重命名为 'Electronic_image_0115.jpg'
# 文件 'image_0116.jpg' 重命名为 'Electronic_image_0116.jpg'
# 文件 'image_0117.jpg' 重命名为 'Electronic_image_0117.jpg'
# 文件 'image_0118.jpg' 重命名为 'Electronic_image_0118.jpg'
# 文件 'image_0119.jpg' 重命名为 'Electronic_image_0119.jpg'
# 文件 'image_0120.jpg' 重命名为 'Electronic_image_0120.jpg'
# 文件 'image_0121.jpg' 重命名为 'Electronic_image_0121.jpg'
# 文件 'image_0122.jpg' 重命名为 'Electronic_image_0122.jpg'
# 文件 'image_0123.jpg' 重命名为 'Electronic_image_0123.jpg'
# 文件 'image_0124.jpg' 重命名为 'Electronic_image_0124.jpg'
# 文件 'image_0125.jpg' 重命名为 'Electronic_image_0125.jpg'
# 文件 'image_0126.jpg' 重命名为 'Electronic_image_0126.jpg'
# 文件 'image_0127.jpg' 重命名为 'Electronic_image_0127.jpg'
# 文件 'image_0128.jpg' 重命名为 'Electronic_image_0128.jpg'
# 文件 'image_0129.jpg' 重命名为 'Electronic_image_0129.jpg'
# 文件 'image_0130.jpg' 重命名为 'Electronic_image_0130.jpg'
# 文件 'image_0131.jpg' 重命名为 'Electronic_image_0131.jpg'
# 文件 'image_0132.jpg' 重命名为 'Electronic_image_0132.jpg'
# 文件 'image_0133.jpg' 重命名为 'Electronic_image_0133.jpg'
# 文件 'image_0134.jpg' 重命名为 'Electronic_image_0134.jpg'
# 文件 'image_0135.jpg' 重命名为 'Electronic_image_0135.jpg'
# 文件 'image_0136.jpg' 重命名为 'Electronic_image_0136.jpg'
# 文件 'image_0137.jpg' 重命名为 'Electronic_image_0137.jpg'
# 文件 'image_0138.jpg' 重命名为 'Electronic_image_0138.jpg'
# 文件 'image_0139.jpg' 重命名为 'Electronic_image_0139.jpg'
# 文件 'image_0140.jpg' 重命名为 'Electronic_image_0140.jpg'
# 文件 'image_0141.jpg' 重命名为 'Electronic_image_0141.jpg'
# 已完成对文件夹 'Electronic' 下所有文件的重命名。
